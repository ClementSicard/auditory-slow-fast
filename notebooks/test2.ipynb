# %%
import pandas as pd

# %%
df = pd.read_pickle("../data/epic-kitchens-100-annotations/filtered_train.pkl")
df.head()
# Out:
#   participant_id video_id narration_timestamp start_timestamp stop_timestamp  \
# 0            P01   P01_01        00:10:39.580     00:10:41.81    00:10:42.83
# 1            P01   P01_01        00:10:39.580     00:10:41.81    00:10:42.83
# 2            P01   P01_01        00:10:50.470     00:10:52.77    00:10:53.83
# 3            P01   P01_01        00:10:50.470     00:10:52.77    00:10:53.83
# 4            P01   P01_01        00:15:10.040     00:15:09.33    00:15:11.48
#
#    start_frame  stop_frame                     narration        verb  \
# 0        38508       38569         throw carrot into bin  throw-into
# 1        38508       38569         throw carrot into bin  throw-into
# 2        39166       39229         throw carrot into bin  throw-into
# 3        39166       39229         throw carrot into bin  throw-into
# 4        54559       54688  throw something into the bin  throw-into
#
#    verb_class  ... noun_class      all_nouns all_noun_classes duration_in_s  \
# ...
