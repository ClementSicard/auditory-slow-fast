# %%
import numpy as np
import pandas as pd
import os
import h5py
from tqdm import tqdm
import time
from datetime import timedelta
import pickle

# %%
SAMPLE_RATE = 24_000
ANNOTATIONS_PATH = "../data/epic-kitchens-100-annotations/EPIC_100_validation.pkl"
VERBS_PATH = "../data/epic-kitchens-100-annotations/EPIC_100_verb_classes.csv"
AUDIO_FILE_PATH = "/scratch/work/ptg/EPIC-KITCHENS/EPIC_audio.hdf5"
VIDEO_DESC_PATH = "../data/epic-kitchens-100-annotations/EPIC_100_video_info.csv"

# %% [markdown]
# ## 1. Load the annotations for the validation set

# %%
df = pd.read_pickle(ANNOTATIONS_PATH)
df.head(10)
# Out:
#              participant_id video_id narration_timestamp start_timestamp  \
# narration_id
# P01_11_0                P01   P01_11        00:00:00.560     00:00:00.00
# P01_11_1                P01   P01_11        00:00:01.700     00:00:01.56
# P01_11_10               P01   P01_11        00:00:48.500     00:00:49.15
# P01_11_100              P01   P01_11        00:05:27.840     00:05:27.28
# P01_11_101              P01   P01_11        00:05:26.840     00:05:27.37
# P01_11_102              P01   P01_11        00:05:32.500     00:05:30.62
# P01_11_103              P01   P01_11        00:05:37.000     00:05:35.56
# P01_11_104              P01   P01_11        00:05:41.590     00:05:41.24
# P01_11_105              P01   P01_11        00:05:50.099     00:05:48.67
# P01_11_106              P01   P01_11        00:05:57.240     00:05:56.18
#
#              stop_timestamp  start_frame  stop_frame             narration  \
# narration_id
# P01_11_0        00:00:01.89            1         113            take plate
# P01_11_1        00:00:02.45           93         147        put down plate
# P01_11_10       00:00:50.95         2949        3057            take paper
# P01_11_100      00:05:31.97        19636       19918            wash cloth
# P01_11_101      00:05:29.86        19642       19791            take cloth
# P01_11_102      00:05:35.02        19837       20101         squeeze cloth
# P01_11_103      00:05:41.14        20133       20468          wipe counter
# P01_11_104      00:05:48.23        20474       20893             wipe sink
# P01_11_105      00:05:56.10        20920       21366  continue wiping sink
# P01_11_106      00:05:57.82        21370       21469         squeeze cloth
#
#                   verb  verb_class     noun  noun_class  all_nouns  \
# narration_id
# P01_11_0          take           0    plate           2    [plate]
# P01_11_1      put-down           1    plate           2    [plate]
# P01_11_10         take           0    paper          49    [paper]
# P01_11_100        wash           2    cloth          17    [cloth]
# P01_11_101        take           0    cloth          17    [cloth]
# P01_11_102     squeeze          18    cloth          17    [cloth]
# P01_11_103        wipe           2  counter          42  [counter]
# P01_11_104        wipe           2     sink          63     [sink]
# P01_11_105        wipe           2     sink          63     [sink]
# P01_11_106     squeeze          18    cloth          17    [cloth]
#
#              all_noun_classes
# narration_id
# P01_11_0                  [2]
# P01_11_1                  [2]
# P01_11_10                [49]
# P01_11_100               [17]
# P01_11_101               [17]
# P01_11_102               [17]
# P01_11_103               [42]
# P01_11_104               [63]
# P01_11_105               [63]
# P01_11_106               [17]

# %%
verbs_df = pd.read_csv(VERBS_PATH, index_col=0)

all_verb_classes = verbs_df.index
all_verbs = verbs_df["key"]

verbs_df.head(10)
# Out:
#          key                                          instances  category
# id
# 0       take  ['collect-from', 'collect-into', 'draw', 'fetc...  retrieve
# 1        put  ['create', 'dose', 'lay', 'lay-down', 'lay-on'...     leave
# 2       wash  ['clean', 'clean-around', 'clean-from', 'clean...     clean
# 3       open  ['lever-open', 'open', 'open-in', 'open-on', '...    access
# 4      close  ['close', 'close-off', 'close-with', 'screw-on...     block
# 5     insert  ['drop-into', 'fit', 'fit-inside', 'insert', '...     leave
# 6    turn-on  ['activate', 'begin', 'ignite', 'light', 'play...    access
# 7        cut  ['chop', 'chop-in', 'chop-off', 'chop-up', 'ch...     split
# 8   turn-off  ['shut-off', 'switch-of', 'switch-off', 'switc...     block
# 9       pour  ['drizzle', 'drizzle-into', 'drizzle-on', 'pou...     merge

# %%
video_df = pd.read_csv(VIDEO_DESC_PATH, index_col=0)
video_df.head()
# Out:
#              duration       fps resolution
# video_id
# P01_01    1652.152817  59.94006  1920x1080
# P01_02     502.134967  59.94006  1920x1080
# P01_03     118.852067  59.94006  1920x1080
# P01_04     105.238467  59.94006  1920x1080
# P01_05    1271.988033  59.94006  1920x1080

# %%
# Load the h5py file for the audio
audio_dataset = h5py.File(AUDIO_FILE_PATH, "r")

# %%
df.head()
# Out:
#              participant_id video_id narration_timestamp start_timestamp  \
# narration_id
# P01_11_0                P01   P01_11        00:00:00.560     00:00:00.00
# P01_11_1                P01   P01_11        00:00:01.700     00:00:01.56
# P01_11_10               P01   P01_11        00:00:48.500     00:00:49.15
# P01_11_100              P01   P01_11        00:05:27.840     00:05:27.28
# P01_11_101              P01   P01_11        00:05:26.840     00:05:27.37
#
#              stop_timestamp  start_frame  stop_frame       narration  \
# narration_id
# P01_11_0        00:00:01.89            1         113      take plate
# P01_11_1        00:00:02.45           93         147  put down plate
# P01_11_10       00:00:50.95         2949        3057      take paper
# P01_11_100      00:05:31.97        19636       19918      wash cloth
# P01_11_101      00:05:29.86        19642       19791      take cloth
#
#                   verb  verb_class   noun  noun_class all_nouns  \
# narration_id
# P01_11_0          take           0  plate           2   [plate]
# P01_11_1      put-down           1  plate           2   [plate]
# P01_11_10         take           0  paper          49   [paper]
# P01_11_100        wash           2  cloth          17   [cloth]
# P01_11_101        take           0  cloth          17   [cloth]
#
#              all_noun_classes
# narration_id
# P01_11_0                  [2]
# P01_11_1                  [2]
# P01_11_10                [49]
# P01_11_100               [17]
# P01_11_101               [17]

# %% [markdown]
# ## 1. Loop over all verbs

# %%
def timestamp_to_sec(timestamp):
    time_parts = timestamp.split(".")
    base_time = time_parts[0]
    microsecond_part = time_parts[1].rstrip("0") if len(time_parts) > 1 else "0"

    if not microsecond_part:
        microsecond_part = "0"

    x = time.strptime(base_time, "%H:%M:%S")

    # Calculate the divisor based on the length of the microsecond part
    divisor = 10 ** len(microsecond_part)

    sec = (
        float(
            timedelta(
                hours=x.tm_hour,
                minutes=x.tm_min,
                seconds=x.tm_sec,
                microseconds=int(microsecond_part),
            ).total_seconds()
        )
        + int(microsecond_part) / divisor
    )
    return sec

# %%
output_dir = "waveforms"
os.makedirs(output_dir, exist_ok=True)

count = 0
# for verb in tqdm(all_verb_classes, unit=" verb"):
for i, verb in enumerate(all_verb_classes, 1):
    verb_actions = df[df["verb_class"] == verb]
    verb_name = verbs_df.loc[verb]["key"]

    verb_waveforms = []
    
    for ii, action in tqdm(
        verb_actions.iterrows(), 
        total=verb_actions.shape[0], 
        unit=" action", 
        desc=f"[{i}/{len(all_verb_classes)}] Getting waveforms for '{verb_name}' ({verb})\t",
    ):
        video_audio = audio_dataset[action.video_id]
        
        # Get start and end indices in the processed audio
        start_idx = int(timestamp_to_sec(action.start_timestamp) * SAMPLE_RATE)
        end_idx = int(timestamp_to_sec(action.stop_timestamp) * SAMPLE_RATE)
        
        # Get the waveform and append it per verb
        wf = video_audio[start_idx:end_idx][()]
        verb_waveforms.append(wf)
        
        count += 1
        
    # Save the verb_waveforms to pickle
    with open(os.path.join(output_dir, f"{verb_name}.pkl"), "wb") as f:
        pickle.dump(verb_waveforms, f)      
        
print(f"Done saving {count:,} actions to {output_dir}/!")
# Out:
# [1/97] Getting waveforms for 'take' (0)	: 100%|██████████| 1937/1937 [00:02<00:00, 732.96 action/s]
# [2/97] Getting waveforms for 'put' (1)	: 100%|██████████| 1709/1709 [00:02<00:00, 590.22 action/s]
# [3/97] Getting waveforms for 'wash' (2)	: 100%|██████████| 1141/1141 [00:01<00:00, 684.15 action/s]
# [4/97] Getting waveforms for 'open' (3)	: 100%|██████████| 810/810 [00:01<00:00, 592.72 action/s]
# [5/97] Getting waveforms for 'close' (4)	: 100%|██████████| 514/514 [00:00<00:00, 902.68 action/s]
# [6/97] Getting waveforms for 'insert' (5)	: 100%|██████████| 608/608 [00:00<00:00, 807.04 action/s]
# [7/97] Getting waveforms for 'turn-on' (6)	: 100%|██████████| 303/303 [00:00<00:00, 731.50 action/s]
# [8/97] Getting waveforms for 'cut' (7)	: 100%|██████████| 292/292 [00:00<00:00, 730.63 action/s]
# [9/97] Getting waveforms for 'turn-off' (8)	: 100%|██████████| 211/211 [00:00<00:00, 755.00 action/s]
# [10/97] Getting waveforms for 'pour' (9)	: 100%|██████████| 242/242 [00:00<00:00, 662.63 action/s]
# [11/97] Getting waveforms for 'mix' (10)	: 100%|██████████| 287/287 [00:00<00:00, 483.04 action/s]
# [12/97] Getting waveforms for 'move' (11)	: 100%|██████████| 141/141 [00:00<00:00, 529.45 action/s]
# [13/97] Getting waveforms for 'remove' (12)	: 100%|██████████| 223/223 [00:00<00:00, 622.38 action/s]
# [14/97] Getting waveforms for 'throw' (13)	: 100%|██████████| 119/119 [00:00<00:00, 628.34 action/s]
# [15/97] Getting waveforms for 'dry' (14)	: 100%|██████████| 97/97 [00:00<00:00, 738.87 action/s]
# [16/97] Getting waveforms for 'shake' (15)	: 100%|██████████| 88/88 [00:00<00:00, 1208.86 action/s]
# [17/97] Getting waveforms for 'scoop' (16)	: 100%|██████████| 53/53 [00:00<00:00, 689.31 action/s]
# [18/97] Getting waveforms for 'adjust' (17)	: 100%|██████████| 64/64 [00:00<00:00, 554.44 action/s]
# [19/97] Getting waveforms for 'squeeze' (18)	: 100%|██████████| 50/50 [00:00<00:00, 1004.79 action/s]
# [20/97] Getting waveforms for 'peel' (19)	: 100%|██████████| 63/63 [00:00<00:00, 697.58 action/s]
# [21/97] Getting waveforms for 'empty' (20)	: 100%|██████████| 48/48 [00:00<00:00, 1180.59 action/s]
# [22/97] Getting waveforms for 'press' (21)	: 100%|██████████| 21/21 [00:00<00:00, 1026.89 action/s]
# [23/97] Getting waveforms for 'flip' (22)	: 100%|██████████| 10/10 [00:00<00:00, 552.76 action/s]
# [24/97] Getting waveforms for 'turn' (23)	: 100%|██████████| 32/32 [00:00<00:00, 307.57 action/s]
# [25/97] Getting waveforms for 'check' (24)	: 100%|██████████| 38/38 [00:00<00:00, 1200.93 action/s]
# [26/97] Getting waveforms for 'scrape' (25)	: 100%|██████████| 8/8 [00:00<00:00, 836.00 action/s]
# [27/97] Getting waveforms for 'fill' (26)	: 100%|██████████| 31/31 [00:00<00:00, 1084.79 action/s]
# [28/97] Getting waveforms for 'apply' (27)	: 100%|██████████| 39/39 [00:00<00:00, 654.35 action/s]
# [29/97] Getting waveforms for 'fold' (28)	: 100%|██████████| 23/23 [00:00<00:00, 645.56 action/s]
# [30/97] Getting waveforms for 'scrub' (29)	: 100%|██████████| 20/20 [00:00<00:00, 885.39 action/s]
# [31/97] Getting waveforms for 'break' (30)	: 100%|██████████| 10/10 [00:00<00:00, 485.33 action/s]
# [32/97] Getting waveforms for 'pull' (31)	: 100%|██████████| 10/10 [00:00<00:00, 148.26 action/s]
# [33/97] Getting waveforms for 'pat' (32)	: 100%|██████████| 7/7 [00:00<00:00, 1959.43 action/s]
# [34/97] Getting waveforms for 'lift' (33)	: 100%|██████████| 8/8 [00:00<00:00, 1912.26 action/s]
# [35/97] Getting waveforms for 'hold' (34)	: 100%|██████████| 10/10 [00:00<00:00, 1868.79 action/s]
# [36/97] Getting waveforms for 'eat' (35)	: 100%|██████████| 19/19 [00:00<00:00, 598.46 action/s]
# [37/97] Getting waveforms for 'wrap' (36)	: 100%|██████████| 29/29 [00:00<00:00, 490.59 action/s]
# [38/97] Getting waveforms for 'filter' (37)	: 100%|██████████| 16/16 [00:00<00:00, 1187.16 action/s]
# [39/97] Getting waveforms for 'look' (38)	: 100%|██████████| 8/8 [00:00<00:00, 1095.87 action/s]
# [40/97] Getting waveforms for 'unroll' (39)	: 100%|██████████| 3/3 [00:00<00:00, 1221.64 action/s]
# [41/97] Getting waveforms for 'sort' (40)	: 100%|██████████| 15/15 [00:00<00:00, 1160.29 action/s]
# [42/97] Getting waveforms for 'hang' (41)	: 100%|██████████| 9/9 [00:00<00:00, 1744.80 action/s]
# [43/97] Getting waveforms for 'sprinkle' (42)	: 100%|██████████| 10/10 [00:00<00:00, 1203.74 action/s]
# [44/97] Getting waveforms for 'rip' (43)	: 100%|██████████| 8/8 [00:00<00:00, 1334.70 action/s]
# [45/97] Getting waveforms for 'spray' (44)	: 100%|██████████| 16/16 [00:00<00:00, 824.98 action/s]
# [46/97] Getting waveforms for 'cook' (45)	: 100%|██████████| 16/16 [00:00<00:00, 659.11 action/s]
# [47/97] Getting waveforms for 'add' (46)	: 100%|██████████| 29/29 [00:00<00:00, 562.52 action/s]
# [48/97] Getting waveforms for 'roll' (47)	: 100%|██████████| 20/20 [00:00<00:00, 1146.09 action/s]
# [49/97] Getting waveforms for 'search' (48)	: 100%|██████████| 8/8 [00:00<00:00, 278.54 action/s]
# [50/97] Getting waveforms for 'crush' (49)	: 100%|██████████| 11/11 [00:00<00:00, 57.81 action/s]
# [51/97] Getting waveforms for 'stretch' (50)	: 0 action [00:00, ? action/s]
# [52/97] Getting waveforms for 'knead' (51)	: 100%|██████████| 23/23 [00:00<00:00, 1382.91 action/s]
# [53/97] Getting waveforms for 'divide' (52)	: 100%|██████████| 8/8 [00:00<00:00, 396.36 action/s]
# [54/97] Getting waveforms for 'set' (53)	: 100%|██████████| 13/13 [00:00<00:00, 1394.60 action/s]
# [55/97] Getting waveforms for 'feel' (54)	: 0 action [00:00, ? action/s]
# [56/97] Getting waveforms for 'rub' (55)	: 100%|██████████| 3/3 [00:00<00:00, 964.73 action/s]
# [57/97] Getting waveforms for 'soak' (56)	: 100%|██████████| 17/17 [00:00<00:00, 1445.55 action/s]
# [58/97] Getting waveforms for 'brush' (57)	: 100%|██████████| 9/9 [00:00<00:00, 1329.32 action/s]
# [59/97] Getting waveforms for 'sharpen' (58)	: 0 action [00:00, ? action/s]
# [60/97] Getting waveforms for 'drop' (59)	: 100%|██████████| 5/5 [00:00<00:00, 1140.13 action/s]
# [61/97] Getting waveforms for 'drink' (60)	: 100%|██████████| 6/6 [00:00<00:00, 283.84 action/s]
# [62/97] Getting waveforms for 'slide' (61)	: 0 action [00:00, ? action/s]
# [63/97] Getting waveforms for 'water' (62)	: 0 action [00:00, ? action/s]
# [64/97] Getting waveforms for 'gather' (63)	: 100%|██████████| 5/5 [00:00<00:00, 1485.87 action/s]
# [65/97] Getting waveforms for 'attach' (64)	: 100%|██████████| 4/4 [00:00<00:00, 1076.77 action/s]
# [66/97] Getting waveforms for 'turn-down' (65)	: 100%|██████████| 5/5 [00:00<00:00, 108.83 action/s]
# [67/97] Getting waveforms for 'coat' (66)	: 0 action [00:00, ? action/s]
# [68/97] Getting waveforms for 'transition' (67)	: 100%|██████████| 11/11 [00:00<00:00, 522.02 action/s]
# [69/97] Getting waveforms for 'wear' (68)	: 100%|██████████| 3/3 [00:00<00:00, 1493.34 action/s]
# [70/97] Getting waveforms for 'measure' (69)	: 100%|██████████| 5/5 [00:00<00:00, 331.52 action/s]
# [71/97] Getting waveforms for 'increase' (70)	: 100%|██████████| 1/1 [00:00<00:00, 990.16 action/s]
# [72/97] Getting waveforms for 'unscrew' (71)	: 100%|██████████| 9/9 [00:00<00:00, 2050.22 action/s]
# [73/97] Getting waveforms for 'wait' (72)	: 100%|██████████| 1/1 [00:00<00:00, 413.72 action/s]
# [74/97] Getting waveforms for 'lower' (73)	: 0 action [00:00, ? action/s]
# [75/97] Getting waveforms for 'form' (74)	: 0 action [00:00, ? action/s]
# [76/97] Getting waveforms for 'smell' (75)	: 100%|██████████| 1/1 [00:00<00:00, 1281.88 action/s]
# [77/97] Getting waveforms for 'use' (76)	: 0 action [00:00, ? action/s]
# [78/97] Getting waveforms for 'grate' (77)	: 0 action [00:00, ? action/s]
# [79/97] Getting waveforms for 'screw' (78)	: 100%|██████████| 4/4 [00:00<00:00, 1242.20 action/s]
# [80/97] Getting waveforms for 'let-go' (79)	: 0 action [00:00, ? action/s]
# [81/97] Getting waveforms for 'finish' (80)	: 100%|██████████| 4/4 [00:00<00:00, 1803.42 action/s]
# [82/97] Getting waveforms for 'stab' (81)	: 100%|██████████| 14/14 [00:00<00:00, 2193.43 action/s]
# [83/97] Getting waveforms for 'serve' (82)	: 100%|██████████| 6/6 [00:00<00:00, 723.59 action/s]
# [84/97] Getting waveforms for 'uncover' (83)	: 100%|██████████| 5/5 [00:00<00:00, 2038.84 action/s]
# [85/97] Getting waveforms for 'unwrap' (84)	: 100%|██████████| 7/7 [00:00<00:00, 795.49 action/s]
# [86/97] Getting waveforms for 'choose' (85)	: 100%|██████████| 4/4 [00:00<00:00, 1008.91 action/s]
# [87/97] Getting waveforms for 'lock' (86)	: 0 action [00:00, ? action/s]
# [88/97] Getting waveforms for 'flatten' (87)	: 0 action [00:00, ? action/s]
# [89/97] Getting waveforms for 'switch' (88)	: 0 action [00:00, ? action/s]
# [90/97] Getting waveforms for 'carry' (89)	: 100%|██████████| 2/2 [00:00<00:00, 1571.78 action/s]
# [91/97] Getting waveforms for 'season' (90)	: 100%|██████████| 7/7 [00:00<00:00, 1372.10 action/s]
# [92/97] Getting waveforms for 'unlock' (91)	: 0 action [00:00, ? action/s]
# [93/97] Getting waveforms for 'prepare' (92)	: 0 action [00:00, ? action/s]
# [94/97] Getting waveforms for 'bake' (93)	: 100%|██████████| 2/2 [00:00<00:00, 1423.25 action/s]
# [95/97] Getting waveforms for 'mark' (94)	: 0 action [00:00, ? action/s]
# [96/97] Getting waveforms for 'bend' (95)	: 0 action [00:00, ? action/s]
# [97/97] Getting waveforms for 'unfreeze' (96)	: 0 action [00:00, ? action/s]
# Done saving 9,668 actions to waveforms/!
